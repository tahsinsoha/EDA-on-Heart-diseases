# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from pandas import ExcelWriter
from pandas import ExcelFile
from IPython.display import display
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('.\heart_disease.csv')

# %%
data.head() # first 5 rows
# Out:
#    Age  Sex  Chest Pain Type  Resting Blood Pressure  Cholestoral  Target
# 0   63    1                3                     145          233       1
# 1   37    1                2                     130          250       1
# 2   41    0                1                     130          204       1
# 3   56    1                1                     120          236       1
# 4   57    0                0                     120          354       1

# %%
data.tail() #last 5 rows
# Out:
#     Age  Sex  Chest Pain Type  Resting Blood Pressure  Cholestoral  Target
# 95   57    1                2                     128          229       0
# 96   61    1                0                     120          260       0
# 97   39    1                0                     118          219       0
# 98   61    0                0                     145          307       0
# 99   57    0                1                     130          236       0

# %%
data.nunique() #unique data
# Out:
# Age                       33
# Sex                        2
# Chest Pain Type            4
# Resting Blood Pressure    23
# Cholestoral               77
# Target                     2
# dtype: int64

# %%
data.isnull().sum() # missing values
# Out:
# Age                       0
# Sex                       0
# Chest Pain Type           0
# Resting Blood Pressure    0
# Cholestoral               0
# Target                    0
# dtype: int64

# %%
data.shape
# Out:
# (100, 6)

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'Chest Pain Type', 'Resting Blood Pressure',
#        'Cholestoral', 'Target'],
#       dtype='object')

# %%
data.describe()
# Out:
#               Age         Sex  Chest Pain Type  Resting Blood Pressure  \
# count  100.000000  100.000000       100.000000              100.000000
# mean    54.700000    0.720000         1.000000              133.380000
# std      8.093519    0.451261         1.044466               15.493746
# min     37.000000    0.000000         0.000000              104.000000
# 25%     49.000000    0.000000         0.000000              120.000000
# 50%     56.000000    1.000000         1.000000              130.000000
# 75%     60.000000    1.000000         2.000000              140.500000
# max     71.000000    1.000000         3.000000              180.000000
#
#        Cholestoral      Target
# count   100.000000  100.000000
# mean    246.630000    0.500000
# std      48.719493    0.502519
# min     164.000000    0.000000
# 25%     215.250000    0.000000
# 50%     239.000000    0.500000
# 75%     270.750000    1.000000
# max     417.000000    1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     100 non-null    int64
#  1   Sex                     100 non-null    int64
#  2   Chest Pain Type         100 non-null    int64
#  3   Resting Blood Pressure  100 non-null    int64
#  4   Cholestoral             100 non-null    int64
#  5   Target                  100 non-null    int64
# dtypes: int64(6)
# memory usage: 4.8 KB

# %%
CP = data['Age']
mean = np.mean(CP)
median=np.median(CP)
mode=stats.mode(CP)
standard_dev=np.std(CP)
variance = np.var(CP)
rangee=np.ptp(CP)

print(mean)
print(median)
print(mode)
print(standard_dev)
print(variance)
print(rangee)
# Out:
# 54.7
# 56.0
# ModeResult(mode=array([58], dtype=int64), count=array([7]))
# 8.052949770115294
# 64.84999999999998
# 34

# %%
CP = data['Sex']
mean = np.mean(CP)
median=np.median(CP)
mode=stats.mode(CP)
standard_dev=np.std(CP)
variance = np.var(CP)
rangee= np.ptp(data['Sex'])

print(mean)
print(median)
print(mode)
print(standard_dev)
print(variance)
print(rangee)
# Out:
# 0.72
# 1.0
# ModeResult(mode=array([1], dtype=int64), count=array([72]))
# 0.4489988864128729
# 0.20159999999999992
# 1

# %%
CP = data['Chest Pain Type']
mean = np.mean(CP)
median=np.median(CP)
mode=stats.mode(CP)
standard_dev=np.std(CP)
variance = np.var(CP)
rangee= np.ptp(data['Chest Pain Type'])

print(mean)
print(median)
print(mode)
print(standard_dev)
print(variance)
print(rangee)
# Out:
# 1.0
# 1.0
# ModeResult(mode=array([0], dtype=int64), count=array([47]))
# 1.0392304845413265
# 1.08
# 3

# %%
CP = data['Resting Blood Pressure']
mean = np.mean(CP)
median=np.median(CP)
mode=stats.mode(CP)
standard_dev=np.std(CP)
variance = np.var(CP)
rangee= np.ptp(data['Resting Blood Pressure'])

print(mean)
print(median)
print(mode)
print(standard_dev)
print(variance)
print(rangee)
# Out:
# 133.38
# 130.0
# ModeResult(mode=array([130], dtype=int64), count=array([16]))
# 15.416082511455365
# 237.65559999999994
# 76

# %%
CP = data['Cholestoral']
mean = np.mean(CP)
median=np.median(CP)
mode=stats.mode(CP)
standard_dev=np.std(CP)
variance = np.var(CP)
rangee= np.ptp(data['Cholestoral'])

print(mean)
print(median)
print(mode)
print(standard_dev)
print(variance)
print(rangee)
# Out:
# 246.63
# 239.0
# ModeResult(mode=array([177], dtype=int64), count=array([4]))
# 48.475283392673425
# 2349.8531000000003
# 253

# %%
CP = data['Target']
mean = np.mean(CP)
median=np.median(CP)
mode=stats.mode(CP)
standard_dev=np.std(CP)
variance = np.var(CP)
rangee= np.ptp(data['Target'])

print(mean)
print(median)
print(mode)
print(standard_dev)
print(variance)
print(rangee)
# Out:
# 0.5
# 0.5
# ModeResult(mode=array([0], dtype=int64), count=array([50]))
# 0.5
# 0.25
# 1

# %%
data['Age'].hist(grid=True, bins=10); 
plt.title('Age distribuition')
# Out:
# Text(0.5, 1.0, 'Age distribuition')

# %%
plt.rcParams['figure.figsize']= (15,8) # reajustar o tamanho da figura 

data[[ 'Age', 'Resting Blood Pressure', 'Cholestoral']].hist();

# %%
data['Sex'] = data['Sex'].map({0:'female', 1:'male'})
data['Target'] = data['Target'].map({0:'Healthy', 1:'Unhealthy'})

plt.rcParams['figure.figsize'] = (10,8)
sns.countplot(x='Target', hue='Sex', data=data);
plt.title('Count of target feature by Sex')
# Out:
# Text(0.5, 1.0, 'Count of target feature by Sex')

# %%
sns.countplot(x='Chest Pain Type', hue='Target', data=data)
# Out:
# <AxesSubplot:xlabel='Chest Pain Type', ylabel='count'>

# %%
sns.scatterplot(x='Age', y='Cholestoral', hue='Target', data = data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Cholestoral'>

# %%
sns.boxplot(x='Sex', y='Cholestoral', data=data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Cholestoral'>

# %%
sns.countplot(x='Sex', hue='Target', data=data, palette='Set2').set_title('Disease classes according to Sex')
# Out:
# Text(0.5, 1.0, 'Disease classes according to Sex')

# %%
sns.countplot(x='Chest Pain Type', hue='Target', data=data, palette='Set2').set_title('Disease classes according to Chest Pain')
# Out:
# Text(0.5, 1.0, 'Disease classes according to Chest Pain')

# %%
continous_features = ['Age', 'Cholestoral','Resting Blood Pressure']  
sns.pairplot(data[continous_features + ['Target']], hue='Target')

# %%
#print(data['Target'])
# gender = {'male': 1,'female': 0}
# data.Sex = [gender[item] for item in data.Sex]
# health = {'Unhealthy': 1,'Healthy': 0}
# data.Target = [health[item] for item in data.Target]

correlation = data.corr()
sns.heatmap(correlation,xticklabels = correlation.columns, yticklabels = correlation.columns,annot =True)
# Out:
# <AxesSubplot:>

# %%
print(data['Target'])
# Out:
# 0     Unhealthy
# 1     Unhealthy
# 2     Unhealthy
# 3     Unhealthy
# 4     Unhealthy
#         ...
# 95      Healthy
# 96      Healthy
# 97      Healthy
# 98      Healthy
# 99      Healthy
# Name: Target, Length: 100, dtype: object

# %%
sns.pairplot(data)

# %%
plt.rcParams['figure.figsize'] = (8,8) 
sns.scatterplot(x='Cholestoral', y='Resting Blood Pressure', hue='Sex', size=None, data=data)
plt.title(' Cholesterol vs Blood pressure in rest')
# Out:
# Text(0.5, 1.0, ' Cholesterol vs Blood pressure in rest')

# %%
# Analyze distribution in age in range 10
print(data.Age.value_counts()[:10])
sns.barplot(x=data.Age.value_counts()[:10].index,
            y=data.Age.value_counts()[:10].values,
            palette='Set2')
plt.xlabel('Age')
plt.ylabel('Age distribution')
# Out:
# 58    7
# 60    7
# 65    6
# 57    6
# 44    6
# 54    6
# 59    5
# 53    5
# 51    4
# 61    4
# Name: Age, dtype: int64
# Text(0, 0.5, 'Age distribution')

# %%
print(data.Sex.value_counts())
data['Sex'].value_counts().plot(kind='bar').set_title('Sex Distribution')
# Out:
# male      72
# female    28
# Name: Sex, dtype: int64
# Text(0.5, 1.0, 'Sex Distribution')

# %%
fig, axes = plt.subplots(nrows = 1, ncols=2)
sns.boxplot(y='Cholestoral', data=data, orient='v', ax=axes[0])
sns.boxplot(y='Resting Blood Pressure', data=data,  orient='v', ax=axes[1]);

# %%
sns.set(style="white") 
plt.rcParams['figure.figsize'] = (15, 10) 
sns.heatmap(data.corr(), annot = True, linewidths=.5)
plt.title('Corelation Between Variables', fontsize = 30)
plt.show()

# %%
# Correlation with Heatmap Visualization 
sns.set(style="white") 
mask = np.zeros_like(data.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

fig, ax = plt.subplots(figsize=(5,5))
cmap = sns.diverging_palette(255, 10, as_cmap=True)
sns.heatmap(data.corr(), mask=mask, annot=True, square=True, cmap=cmap,vmin=-1, vmax=1, ax=ax)  

bottom, top = ax.get_ylim()
ax.set_ylim(bottom+0.5, top-0.5)
# Out:
# (4.5, -0.5)
